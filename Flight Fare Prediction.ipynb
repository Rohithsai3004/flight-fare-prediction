# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# # Reading file

# %%
df = pd.read_excel(r"Data_Train.xlsx")
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# ### Dropping Null Values
# Since the number of null data is very low, I prefer to just drop them.

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# # Preprocessing
# ### Extracting the day and the month from the data by converting the Date_of_Journey column into date-time format
#
# It is to note that date of journey does not reveal the special event that might be there on that date which can have an impact on the price of the ticket of our flight. For example, the fare can be higher during days of months that may have holidays/festivals.

# %%
def refine_date_of_journey(df):
    df["Journey_day"] = pd.to_datetime(df["Date_of_Journey"], format = "%d/%m/%Y").dt.day
    df["Journey_month"] = pd.to_datetime(df["Date_of_Journey"], format = "%d/%m/%Y").dt.month
    df.drop(columns="Date_of_Journey", inplace = True)
    return df

# %%
df = refine_date_of_journey(df)
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Journey_day  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897           24
# 1         13:15   7h 25m     2 stops         No info   7662            1
# 2  04:25 10 Jun      19h     2 stops         No info  13882            9
# 3         23:30   5h 25m      1 stop         No info   6218           12
# 4         21:35   4h 45m      1 stop         No info  13302            1
#
#    Journey_month
# 0              3
# 1              5
# 2              6
# 3              5
# 4              3

# %% [markdown]
# ### Extracting Hour and Minute from the Dep_Time column and Arrival_Time column
#
# The clock display format HH:MM cannot be understood by the algorithm so I converted it into two columns of hours and minutes making it numerical from object data type

# %%
def refine_journey_time(df):   
    df["Dep_hour"] = pd.to_datetime(df["Dep_Time"]).dt.hour
    df["Dep_min"] = pd.to_datetime(df["Dep_Time"]).dt.minute
    df["Arrival_hour"] = pd.to_datetime(df["Arrival_Time"]).dt.hour
    df["Arrival_min"] = pd.to_datetime(df["Arrival_Time"]).dt.minute
    df.drop(columns = ["Dep_Time","Arrival_Time"], inplace = True)
    return df

# %%
df = refine_journey_time(df)
df.head()
# Out:
# C:\Users\RohithSai\AppData\Local\Temp\ipykernel_26224\1608775238.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Dep_hour"] = pd.to_datetime(df["Dep_Time"]).dt.hour
# C:\Users\RohithSai\AppData\Local\Temp\ipykernel_26224\1608775238.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Dep_min"] = pd.to_datetime(df["Dep_Time"]).dt.minute
# C:\Users\RohithSai\AppData\Local\Temp\ipykernel_26224\1608775238.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Arrival_hour"] = pd.to_datetime(df["Arrival_Time"]).dt.hour
# ...

# %% [markdown]
# ### Extracting hours and minutes from Duration
# Adding 0 minutes where minute is missing and 0 hours where hour is missing and storing hours and minutes in separate lists then converting them to dataframe columns.

# %%
def refine_duration(df):
    # creating some lists
    duration = list(df["Duration"])
    duration_hour = []
    duration_min = []
    
    # Adding 0 minutes where minute is missing and 0 hours where hour is missing
    for i in range(len(duration)):
        if(len(duration[i].split()) != 2):
            if("h" in duration[i]):
                duration_hour.append(int(duration[i][:-1]))
                duration_min.append(0)
            else:
                duration_hour.append(0)
                duration_min.append(int(duration[i][:-1]))
        else:
            duration_hour.append(int(duration[i].split()[0][:-1]))
            duration_min.append(int(duration[i].split()[1][:-1]))
            
    # Creating separate columns in the dataframe
    df["Duration_hours"] = duration_hour
    df["Duration_min"] = duration_min
    df.drop(columns = "Duration", inplace = True)
    
    return df

# %%
df = refine_duration(df)
df.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0         No info   3897           24              3        22       20
# 1         No info   7662            1              5         5       50
# 2         No info  13882            9              6         9       25
# 3         No info   6218           12              5        18        5
# 4         No info  13302            1              3        16       50
#
#    Arrival_hour  Arrival_min  Duration_hours  Duration_min
# ...

# %% [markdown]
# # Handling Categorical Data

# %%
df["Airline"].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
df["Source"].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
df["Destination"].value_counts()
# Out:
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
# Catplot t0 visualize the variation of prices with respect to the airline
sns.catplot(y = "Price", x = "Airline", data = df.sort_values("Price", ascending = False), kind="boxen", height=6, aspect=3)
plt.show()

# %% [markdown]
# I was thinking about target encoding but the difference between means of the prices of the arilines is very less

# %%
# Catplot to visualize the variation of prices with respect to the source
sns.catplot(y = "Price", x = "Source", data = df.sort_values("Price", ascending = False), kind="boxen", height=6, aspect=3)
plt.show()

# %%
# Catplot to visualize the variation of prices with respect to the destination
sns.catplot(y = "Price", x = "Destination", data = df.sort_values("Price", ascending = False), kind="boxen", height=6, aspect=3)
plt.show()

# %% [markdown]
# ### Applying one hot encoding on "Airline", "Source", "Destination" columns

# %%
cat_col = ["Airline", "Source", "Destination"]
dummy = pd.get_dummies(df[cat_col], drop_first=True)
dummy.head()
# Out:
#    Airline_Air India  Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 0              False          False            True                False
# 1               True          False           False                False
# 2              False          False           False                 True
# 3              False          False            True                False
# 4              False          False            True                False
#
#    Airline_Jet Airways Business  Airline_Multiple carriers  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
#
#    Airline_Multiple carriers Premium economy  Airline_SpiceJet  \
# 0                                      False             False
# ...

# %%
# merging the summy and main df after dropping respective columns in df
df.drop(columns = cat_col, inplace=True)
df = pd.concat((df, dummy), axis=1)
df.head()
# Out:
#                    Route Total_Stops Additional_Info  Price  Journey_day  \
# 0              BLR → DEL    non-stop         No info   3897           24
# 1  CCU → IXR → BBI → BLR     2 stops         No info   7662            1
# 2  DEL → LKO → BOM → COK     2 stops         No info  13882            9
# 3        CCU → NAG → BLR      1 stop         No info   6218           12
# 4        BLR → NAG → DEL      1 stop         No info  13302            1
#
#    Journey_month  Dep_hour  Dep_min  Arrival_hour  Arrival_min  ...  \
# 0              3        22       20             1           10  ...
# 1              5         5       50            13           15  ...
# 2              6         9       25             4           25  ...
# 3              5        18        5            23           30  ...
# 4              3        16       50            21           35  ...
#
#    Airline_Vistara Premium economy  Source_Chennai  Source_Delhi  \
# ...

# %% [markdown]
# ### Handling Total_Stops

# %%
df["Total_Stops"].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
df.replace({"1 stop":1, "non-stop":0, "2 stops":2, "3 stops": 3, "4 stops": 4}, inplace = True)
# Out:
# C:\Users\RohithSai\AppData\Local\Temp\ipykernel_26224\660149257.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"1 stop":1, "non-stop":0, "2 stops":2, "3 stops": 3, "4 stops": 4}, inplace = True)

# %% [markdown]
# ### Additional_Info column

# %%
df["Additional_Info"].value_counts()
# Out:
# Additional_Info
# No info                         8344
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: count, dtype: int64

# %% [markdown]
# The information contained in Route column can be explained by number of stops too, so we'll drop it and Additional_Info has majority of values as no info so we'll drop it too.

# %%
# Dropping Route and Additional_Info
df.drop(columns = ["Route","Additional_Info"], inplace = True)

# %%
df.head()
# Out:
#    Total_Stops  Price  Journey_day  Journey_month  Dep_hour  Dep_min  \
# 0            0   3897           24              3        22       20
# 1            2   7662            1              5         5       50
# 2            2  13882            9              6         9       25
# 3            1   6218           12              5        18        5
# 4            1  13302            1              3        16       50
#
#    Arrival_hour  Arrival_min  Duration_hours  Duration_min  ...  \
# 0             1           10               2            50  ...
# 1            13           15               7            25  ...
# 2             4           25              19             0  ...
# 3            23           30               5            25  ...
# 4            21           35               4            45  ...
#
#    Airline_Vistara Premium economy  Source_Chennai  Source_Delhi  \
# 0                            False           False         False
# ...

# %% [markdown]
# # Feature Selection

# %%
df.shape
# Out:
# (10682, 30)

# %%
temp = df.iloc[:,0:10]
plt.figure(figsize=(15,15))
sns.heatmap(temp.corr(), annot=True, square=True, cmap="RdYlGn_r")
plt.show()

# %%
# Separating independent and dependent features
X = df.drop(columns = "Price")
Y = df["Price"]

# %%
# Taking a look at important features
from sklearn.ensemble import ExtraTreesRegressor
ETR = ExtraTreesRegressor()
ETR.fit(X,Y)

# Visualizing Results
plt.figure(figsize=(15,10))
feat_imp = pd.Series(ETR.feature_importances_, index=X.columns)
feat_imp.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# # Fitting the model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# Scaler
scaler1 = MinMaxScaler()
scaler2 = StandardScaler()

def scaler(X, scaler="standard"):
    if(scaler=="standard"):
        return scaler1.fit_transform(X)
    else:
        return scaler2.fit_transform(X)

# %%
X1 = scaler(X, scaler="standard")

#splitting into train and test set
xtrain, xtest, ytrain, ytest = train_test_split(X1,Y, test_size=0.15, random_state=51)

#Training the model
rf = RandomForestRegressor()
rf.fit(xtrain, ytrain)

test_pred = rf.predict(xtest)
train_pred = rf.predict(xtrain)



print("Test R2: ", r2_score(test_pred, ytest))
print("Test RMSE: ", np.sqrt(mean_squared_error(test_pred, ytest)))
print("Train R2: ", r2_score(train_pred, ytrain))
print("Train RMSE: ", np.sqrt(mean_squared_error(train_pred, ytrain)))
# Out:
# Test R2:  0.8234526766998215
# Test RMSE:  1794.4960070853695
# Train R2:  0.9469644981728086
# Train RMSE:  1016.7922365890694

# %%
sns.displot(ytest-test_pred, kde=True)
plt.show()

# %%
from scipy.stats import norm
from scipy.stats import skew
from scipy import stats
# Plot Histogram
sns.distplot(Y , fit=norm)

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(Y)
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice distribution')

fig = plt.figure()
res = stats.probplot(Y, plot=plt)
plt.show()

print("Skewness: %f" % Y.skew())
print("Kurtosis: %f" % Y.kurt())
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\RohithSai\AppData\Local\Temp\ipykernel_26224\707300691.py:10: SyntaxWarning: invalid escape sequence '\m'
#   plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
# C:\Users\RohithSai\AppData\Local\Temp\ipykernel_26224\707300691.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y , fit=norm)
#  mu = 9087.21 and sigma = 4611.33
# Skewness: 1.812405
# Kurtosis: 13.301937

# %%
Y_log = np.log(Y)

# Plot Histogram
sns.distplot(Y_log , fit=norm)

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(Y_log)
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice distribution')

fig = plt.figure()
res = stats.probplot(Y_log, plot=plt)
plt.show()

print("Skewness: %f" % Y_log.skew())
print("Kurtosis: %f" % Y_log.kurt())
# Out:
#  mu = 8.99 and sigma = 0.51
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\RohithSai\AppData\Local\Temp\ipykernel_26224\1047122365.py:9: SyntaxWarning: invalid escape sequence '\m'
#   plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
# C:\Users\RohithSai\AppData\Local\Temp\ipykernel_26224\1047122365.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_log , fit=norm)
# Skewness: -0.254763
# Kurtosis: -0.402302

# %% [markdown]
# ### Taking log transform of dependent feature

# %%
X1 = scaler(X, scaler="standard")
Y_log = np.log(Y)
#splitting into train and test set
xtrain, xtest, ytrain, ytest = train_test_split(X1,Y_log, test_size=0.15, random_state=51)

# Training the XGBoost Regressor
ada = AdaBoostRegressor()
ada.fit(xtrain, ytrain)

# Predicting with AdaBoost Regressor
ada_test_pred = ada.predict(xtest)
ada_train_pred = ada.predict(xtrain)

# Reversing the log transformation
ada_test_pred_exp = np.exp(ada_test_pred)
ada_train_pred_exp = np.exp(ada_train_pred)

# Evaluating AdaBoost Regressor
print("AdaBoost Test R2: ", r2_score(ytest_exp, ada_test_pred_exp))
print("AdaBoost Test RMSE: ", np.sqrt(mean_squared_error(ytest_exp, ada_test_pred_exp)))
print("AdaBoost Train R2: ", r2_score(ytrain_exp, ada_train_pred_exp))
print("AdaBoost Train RMSE: ", np.sqrt(mean_squared_error(ytrain_exp, ada_train_pred_exp)))
# Out:
# AdaBoost Test R2:  0.5722353193619504
# AdaBoost Test RMSE:  2838.517367314984
# AdaBoost Train R2:  0.5639911763376697
# AdaBoost Train RMSE:  3075.2271984832955

# %%
X1 = scaler(X, scaler="standard")
Y_log = np.log(Y)
#splitting into train and test set
xtrain, xtest, ytrain, ytest = train_test_split(X1,Y_log, test_size=0.15, random_state=51)

# Training the XGBoost Regressor
svr = SVR()
svr.fit(xtrain, ytrain)

# Predicting with SVR
svr_test_pred = svr.predict(xtest)
svr_train_pred = svr.predict(xtrain)

# Reversing the log transformation
svr_test_pred_exp = np.exp(svr_test_pred)
svr_train_pred_exp = np.exp(svr_train_pred)

# Evaluating SVR
print("SVR Test R2: ", r2_score(ytest_exp, svr_test_pred_exp))
print("SVR Test RMSE: ", np.sqrt(mean_squared_error(ytest_exp, svr_test_pred_exp)))
print("SVR Train R2: ", r2_score(ytrain_exp, svr_train_pred_exp))
print("SVR Train RMSE: ", np.sqrt(mean_squared_error(ytrain_exp, svr_train_pred_exp)))
# Out:
# SVR Test R2:  0.7936279747258153
# SVR Test RMSE:  1971.5804690929212
# SVR Train R2:  0.7828263800040162
# SVR Train RMSE:  2170.366628823248

# %%
X1 = scaler(X, scaler="standard")
Y_log = np.log(Y)
#splitting into train and test set
xtrain, xtest, ytrain, ytest = train_test_split(X1,Y_log, test_size=0.15, random_state=51)

# Training the XGBoost Regressor
xgb = XGBRegressor()
xgb.fit(xtrain, ytrain)

# Predicting with XGBoost Regressor
xgb_test_pred = xgb.predict(xtest)
xgb_train_pred = xgb.predict(xtrain)

# Reversing the log transformation
ytrain_exp = np.exp(ytrain)
ytest_exp = np.exp(ytest)
xgb_test_pred_exp = np.exp(xgb_test_pred)
xgb_train_pred_exp = np.exp(xgb_train_pred)

# Evaluating XGBoost Regressor
print("XGBoost Test R2: ", r2_score(ytest_exp, xgb_test_pred_exp))
print("XGBoost Test RMSE: ", np.sqrt(mean_squared_error(ytest_exp, xgb_test_pred_exp)))
print("XGBoost Train R2: ", r2_score(ytrain_exp, xgb_train_pred_exp))
print("XGBoost Train RMSE: ", np.sqrt(mean_squared_error(ytrain_exp, xgb_train_pred_exp)))
# Out:
# XGBoost Test R2:  0.8612385682154632
# XGBoost Test RMSE:  1616.6778211472558
# XGBoost Train R2:  0.9248852131378993
# XGBoost Train RMSE:  1276.4161412688993

# %%
X1 = scaler(X, scaler="standard")
Y_log = np.log(Y)
#splitting into train and test set
xtrain, xtest, ytrain, ytest = train_test_split(X1,Y_log, test_size=0.15, random_state=51)

#Training the model
rf = RandomForestRegressor()
rf.fit(xtrain, ytrain)

test_pred = rf.predict(xtest)
train_pred = rf.predict(xtrain)

ytrain = np.exp(ytrain)
ytest = np.exp(ytest)
test_pred = np.exp(test_pred)
train_pred = np.exp(train_pred)

print("Test R2: ", r2_score(test_pred, ytest))
print("Test RMSE: ", np.sqrt(mean_squared_error(test_pred, ytest)))
print("Train R2: ", r2_score(train_pred, ytrain))
print("Train RMSE: ", np.sqrt(mean_squared_error(train_pred, ytrain)))
# Out:
# Test R2:  0.8258321732341637
# Test RMSE:  1754.0498131977797
# Train R2:  0.9355770900767711
# Train RMSE:  1096.5527598202882
